# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('winequality-red.csv')
df['free sulfur dioxide'] = np.log(1 + df['free sulfur dioxide'])
# fill the missing values
for col, value in df.items():
    if col != 'type':
        df[col] = df[col].fillna(df[col].mean())
df['quality'] = [1 if x > 7 else 0 for x in df['quality']]
X = df.drop(columns=['quality'])
y = df['quality']

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# Equilibrio de clases
oversample = SMOTE(k_neighbors=4)
X, y = oversample.fit_resample(X, y)

# División del conjunto de datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Escalamiento de características
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Definir la arquitectura de la red neuronal
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(11,)))
model.add(Dropout(0.2))  # Capa de dropout para regularización
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)  # Ajuste de la tasa de aprendizaje
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluar el modelo
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 75/75 [==============================] - 1s 4ms/step - loss: 0.6095 - accuracy: 0.7225 - val_loss: 0.5426 - val_accuracy: 0.8900
# Epoch 2/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5232 - accuracy: 0.8604 - val_loss: 0.4658 - val_accuracy: 0.9001
# Epoch 3/10
# 75/75 [==============================] - 0s 3ms/step - loss: 0.4591 - accuracy: 0.8790 - val_loss: 0.4053 - val_accuracy: 0.9027
# Epoch 4/10
# 75/75 [==============================] - 0s 6ms/step - loss: 0.4040 - accuracy: 0.8891 - val_loss: 0.3571 - val_accuracy: 0.9115
# Epoch 5/10
# 75/75 [==============================] - 0s 6ms/step - loss: 0.3596 - accuracy: 0.9038 - val_loss: 0.3210 - val_accuracy: 0.9102
# Epoch 6/10
# 75/75 [==============================] - 0s 3ms/step - loss: 0.3276 - accuracy: 0.9051 - val_loss: 0.2941 - val_accuracy: 0.9140
# Epoch 7/10
# 75/75 [==============================] - 0s 5ms/step - loss: 0.3024 - accuracy: 0.9114 - val_loss: 0.2740 - val_accuracy: 0.9178
# Epoch 8/10
# 75/75 [==============================] - 1s 7ms/step - loss: 0.2849 - accuracy: 0.9161 - val_loss: 0.2585 - val_accuracy: 0.9191
# Epoch 9/10
# 75/75 [==============================] - 0s 6ms/step - loss: 0.2723 - accuracy: 0.9199 - val_loss: 0.2463 - val_accuracy: 0.9229
# Epoch 10/10
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2506 - accuracy: 0.9228 - val_loss: 0.2360 - val_accuracy: 0.9241
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2360 - accuracy: 0.9241
# Loss: 0.23602785170078278
# Accuracy: 0.9241466522216797

# %%
# Equilibrio de clases
oversample = SMOTE(k_neighbors=4)
X, y = oversample.fit_resample(X, y)

# División del conjunto de datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Escalamiento de características
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Definir la arquitectura de la red neuronal
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(11,)))
model.add(Dropout(0.2))  # Capa de dropout para regularización
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)  # Ajuste de la tasa de aprendizaje
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

# Evaluar el modelo
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 75/75 [==============================] - 1s 4ms/step - loss: 0.3952 - accuracy: 0.8574 - val_loss: 0.2509 - val_accuracy: 0.9090
# Epoch 2/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2313 - accuracy: 0.9237 - val_loss: 0.1998 - val_accuracy: 0.9292
# Epoch 3/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.9435 - val_loss: 0.1727 - val_accuracy: 0.9431
# Epoch 4/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1581 - accuracy: 0.9536 - val_loss: 0.1627 - val_accuracy: 0.9406
# Epoch 5/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9616 - val_loss: 0.1518 - val_accuracy: 0.9494
# Epoch 6/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1389 - accuracy: 0.9599 - val_loss: 0.1372 - val_accuracy: 0.9583
# Epoch 7/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9658 - val_loss: 0.1360 - val_accuracy: 0.9558
# Epoch 8/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1199 - accuracy: 0.9671 - val_loss: 0.1245 - val_accuracy: 0.9595
# Epoch 9/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9709 - val_loss: 0.1138 - val_accuracy: 0.9646
# Epoch 10/10
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.9709 - val_loss: 0.1083 - val_accuracy: 0.9671
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1083 - accuracy: 0.9671
# Loss: 0.10830757766962051
# Accuracy: 0.9671302437782288

# %%
# Equilibrio de clases
oversample = SMOTE(k_neighbors=4)
X, y = oversample.fit_resample(X, y)

# División del conjunto de datos
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Escalamiento de características
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Definir la arquitectura de la red neuronal
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(11,)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compilar el modelo
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)  # Ajuste de la tasa de aprendizaje
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo
model.fit(X_train, y_train, epochs=25, batch_size=32, validation_data=(X_test, y_test))

# Evaluar el modelo
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Loss: {loss}')
print(f'Accuracy: {accuracy}')

tf.saved_model.save(model, 'best_red_model')
# Out:
# Epoch 1/25
# 75/75 [==============================] - 2s 9ms/step - loss: 0.4548 - accuracy: 0.7967 - val_loss: 0.2376 - val_accuracy: 0.9128
# Epoch 2/25
# 75/75 [==============================] - 0s 6ms/step - loss: 0.2409 - accuracy: 0.9199 - val_loss: 0.1951 - val_accuracy: 0.9267
# Epoch 3/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1989 - accuracy: 0.9363 - val_loss: 0.1626 - val_accuracy: 0.9393
# Epoch 4/25
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1648 - accuracy: 0.9494 - val_loss: 0.1517 - val_accuracy: 0.9482
# Epoch 5/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 0.9528 - val_loss: 0.1409 - val_accuracy: 0.9520
# Epoch 6/25
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1384 - accuracy: 0.9557 - val_loss: 0.1309 - val_accuracy: 0.9532
# Epoch 7/25
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1276 - accuracy: 0.9620 - val_loss: 0.1132 - val_accuracy: 0.9608
# Epoch 8/25
# 75/75 [==============================] - 0s 5ms/step - loss: 0.1143 - accuracy: 0.9654 - val_loss: 0.1147 - val_accuracy: 0.9608
# Epoch 9/25
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1046 - accuracy: 0.9684 - val_loss: 0.0958 - val_accuracy: 0.9671
# Epoch 10/25
# 75/75 [==============================] - 0s 6ms/step - loss: 0.1019 - accuracy: 0.9696 - val_loss: 0.0829 - val_accuracy: 0.9760
# Epoch 11/25
# 75/75 [==============================] - 1s 8ms/step - loss: 0.0921 - accuracy: 0.9739 - val_loss: 0.0893 - val_accuracy: 0.9684
# Epoch 12/25
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0835 - accuracy: 0.9764 - val_loss: 0.0820 - val_accuracy: 0.9697
# Epoch 13/25
# 75/75 [==============================] - 0s 6ms/step - loss: 0.0822 - accuracy: 0.9768 - val_loss: 0.0714 - val_accuracy: 0.9785
# Epoch 14/25
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0784 - accuracy: 0.9785 - val_loss: 0.0679 - val_accuracy: 0.9785
# Epoch 15/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9798 - val_loss: 0.0651 - val_accuracy: 0.9785
# Epoch 16/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9806 - val_loss: 0.0668 - val_accuracy: 0.9772
# Epoch 17/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0692 - accuracy: 0.9785 - val_loss: 0.0549 - val_accuracy: 0.9810
# Epoch 18/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0555 - accuracy: 0.9848 - val_loss: 0.0513 - val_accuracy: 0.9823
# Epoch 19/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0642 - accuracy: 0.9814 - val_loss: 0.0466 - val_accuracy: 0.9823
# Epoch 20/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0559 - accuracy: 0.9836 - val_loss: 0.0646 - val_accuracy: 0.9772
# Epoch 21/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0540 - accuracy: 0.9840 - val_loss: 0.0408 - val_accuracy: 0.9886
# Epoch 22/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0515 - accuracy: 0.9861 - val_loss: 0.0469 - val_accuracy: 0.9861
# Epoch 23/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0517 - accuracy: 0.9865 - val_loss: 0.0430 - val_accuracy: 0.9874
# Epoch 24/25
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0484 - accuracy: 0.9861 - val_loss: 0.0384 - val_accuracy: 0.9886
# Epoch 25/25
# 75/75 [==============================] - 0s 4ms/step - loss: 0.0522 - accuracy: 0.9869 - val_loss: 0.0354 - val_accuracy: 0.9899
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9899
# Loss: 0.03542345389723778
# Accuracy: 0.9898862242698669
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: best_red_model\assets
# INFO:tensorflow:Assets written to: best_red_model\assets
